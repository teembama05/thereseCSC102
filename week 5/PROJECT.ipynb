# %%
import pandas as pd
import csv

print("Welcome to JT-Ventures")

def jtventures (str):
    lastname = str(input("What is your surname?: "))
    firstname = str(input("What is your firstname?: "))
    department = str(input("What department are you in?: "))
    
    def confirmation_csv (lname, fname, dept, csv_file):
        with open (csv_file, "r") as file:
            reader = csv.reader(file)
            for row in reader:
                if lname == row[1] and fname == row[2] and dept == row[3]:
                    print(f"Hello {lastname} {firstname} from {department}")
                    
                    return
            print("This data is not contained in our database.")
    confirmation_csv(lastname.upper(), firstname.capitalize(), department.capitalize(), "jt-ventures.csv")
    print(lastname.upper(), firstname.capitalize(), department.capitalize())
    
    
    data = pd.read_csv("jt-ventures.csv")
    print(data)
    
jtventures(str)
# Out:
# Welcome to JT-Ventures
# What is your surname?: ATELLY
# What is your firstname?: DANIEL
# What department are you in?: DELIVERY
# Hello ATELLY DANIEL from DELIVERY
# ATELLY Daniel Delivery
#     S/N           SURNAME     FIRST NAME      DEPARTMENT
# 0     1          ADENIRAN  Oluwatamilore       Logistics
# 1     2           ADEWUMI        Ayomide      Accounting
# 2     3       ADOH-AJAGBE          Oshim        Delivery
# 3     4  AGBAKURU- \NWOGU    Chukwunonye      Accounting
# 4     5         AGBAKWURU     Chiemeziem       Logistics
# 5     6            AKINDE   Oluwatimehin      Accounting
# 6     7            ARNIKA          Osose       Logistics
# 7     8            ATELLY         Daniel        Delivery
# 8     9             AZOGU      Onyekachi        Delivery
# 9    10            BETURE         Shalom        Delivery
# 10   11          CHUKWUMA           Nedi       Logistics
# 11   12               EBI      Stephanie      Accounting
# ...

# %%
print("WELCOME TO YEGA SERVICES!!!")

product =str(input("What would you like to deliver? "))
weight =int(input("How much does it weight (in kg)? "))

if weight >= 10:
    location = str(input("Where would you like it to be delivered to ? "))
    if location == "Ibeju-Lekki" or "Ibeju" or "ibeju" or "ibeju-lekki":
                   print("Your delivery costs #2000.00")
                   print("Have a nice day, Thanks for choosing us")
    elif location == "Epe" or "epe":
                   print("Your delivery costs #5000.00")
                   print("Have a nice day, Thanks for choosing us")
    else:
                   print("Sorry we do not deliver to that location")
elif weight < 10:
    location == str(input("Where would you like it to be delivered to ? "))
    if location == "Ibeju-Lekki" or "Ibeju" or "ibeju" or "ibeju-lekki":
                   print("Your delivery costs #1500.00")
                   print("Have a nice day, Thanks for choosing us")
    elif location == "Epe" or "epe":
                   print("Your delivery costs #4000.00")
                   print("Have a nice day, Thanks for choosing us")
    else:
                   print("Sorry we do not deliver to that location")
else:
                   print("Sorry we do not deliver that yet ")
# Out:
# WELCOME TO YEGA SERVICES!!!
# What would you like to deliver? top
# How much does it weight (in kg)? 15
# Where would you like it to be delivered to ? epe
# Your delivery costs #2000.00
# Have a nice day, Thanks for choosing us

# %%
#impoting pandas as pd
import pandas as pd
print("Welcome to the Pan-Atlantic University admission portal")

course = str(input("What course would you like to apply for?: "))

if course == "masscom":
    def masscom():
        fname = str(input("Candidates's First Name: "))
        lname = str(input("Candidate's Last Name: "))
        
        jambscore = int(input("Candidate's Jamb Score: "))
        
        print("The requirements for Mass Comunication are:")
        print("A Score of 220 or above in JAMB")
        print("and at least 5 credits in English, Mathematics,Literarure,Government,History, Commerce, Business studies or Marketing")
        print("A1= 75-100 \n B2 = 70-74 \nB3 = 65-69 \n C4 = 60-64 \n D7 45-49 \n E8 = 40-44 \n F9 = 0-39")
        print("Enter Your Grade for each subject")
        
        english = str(input("English: "))
        math = str(input("Mathematics: "))
        physics = str(input("Literature: "))  
        chemistry = str(input("Government: "))
        geo_bio_econs = str(input("History, Commerce, Business studies or Marketing"))
        subjects = {english, math, physics, chemistry, geo_bio_econs}
        
        if jambscore < 220.0 or english in {"D7","E8", "F9"} or math in {"D7","E8", "F9"} or physics in {"D7","E8", "F9"} or chemistry in {"D7","E8", "F9"} or geo_bio_econs in {"D7","E8", "F9"}:
            print("Sorry you do not meet the requirements to be admitted for Mass Communication")
            data ["First Name"] = [fname]
            data ["Last Name"] = [lname]
            data ["Jambscore"] = [jambscore]
            data ["English"] = [english]
            data ["Mathematics"] = [math]
            data ["Literarure"] = [physics]
            data ["Government"] = [chemistry]
            data ["History, Commerce, Business studies or Marketing"] = [geo_ bio_econs]
            
            df = pd.DataFrame(data)
            df.to_csv("not-admitted.csv", index=False)
        
        else:
            print("CONGRATULATIONS!, You have been admitted to study Mass Communication")
            data ["First Name"] = [fname]
            data ["Last Name"] = [lname]
            data ["Jambscore"] = [jambscore]
            data ["English"] = [english]
            data ["Mathematics"] = [math]
            data ["Literature"] = [physics]
            data ["Government"] = [chemistry]
            data ["History, Commerce, Business studies or Marketing"] = [geo_ bio_econs]
            
            df = pd.DataFrame(data)
            df.to_csv("admitted.csv", index=False)
    
    masscom()

if course == "Computer Science":
    def computer():
        fname = str(input("Candidates's First Name: "))
        lname = str(input("Candidate's Last Name: "))
        
        jambscore = int(input("Candidate's Jamb Score: "))
        
        print("The requirements for Mass Communication are:")
        print("A Score of 230 or above in JAMB")
        print("and at least 5 credits in English, Mathematics, Physics, Chemistry and either of Geography, Biology or Economics")
        print("A1= 75-100 \n B2 = 70-74 \nB3 = 65-69 \n C4 = 60-64 \n D7 45-49 \n")
        print("Enter Your Grade for each subject")
        
        english = str(input("English: "))
        math = str(input("Mathematics: "))
        physics = str(input("Physics: "))  
        chemistry = str(input("Chemistry: "))
        geo_bio_econs = str(input("Geography or Biology or Economics: "))
        
        subjects = {english, math, physics, chemistry, geo_bio_econs}
        
        if jambscore < 230.0 or english in {"D7","E8", "F9"} or math in {"D7","E8", "F9"} or physics in {"D7","E8", "F9"} or chemistry in {"D7","E8", "F9"} or geo_bio_econs in {"D7","E8", "F9"}:
            print("Sorry you do not meet the requirements to be admitted for Computer Science")
            data ["First Name"] = [fname]
            data ["Last Name"] = [lname]
            data ["Jambscore"] = [jambscore]
            data ["English"] = [english]
            data ["Mathematics"] = [math]
            data ["Physics"] = [physics]
            data ["Chemistry"] = [chemistry]
            data ["Geography, Biology, Economics"] = [geo_ bio_econs]
            
            df = pd.DataFrame(data)
            df.to_csv("not-admitted.csv", index=False)
        
        else:
            print("CONGRATULATIONS!, You have been admitted to study Computer Science")
            data ["First Name"] = [fname]
            data ["Last Name"] = [lname]
            data ["Jambscore"] = [jambscore]
            data ["English"] = [english]
            data ["Mathematics"] = [math]
            data ["Physics"] = [physics]
            data ["Chemistry"] = [chemistry]
            data ["Geography, Biology, Economics"] = [geo_ bio_econs]
            
            df = pd.DataFrame(data)
            df.to_csv("admitted.csv", index=False)
    
    computer()
# Out:
#   Cell In[10], line 36
#     data ["History, Commerce, Business studies or Marketing"] = [geo_ bio_econs]
#                                                                  ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
